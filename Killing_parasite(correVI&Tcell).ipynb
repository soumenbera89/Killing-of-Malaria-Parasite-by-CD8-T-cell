# %%
# Correlation between VI and CD8 T cells/parasite
import pandas as pd
import numpy as np
import os
os.chdir("/Users/soumenbera/Documents/killing_Tcells")
data = pd.read_excel('Data_killing_23July2018-curated-final.xlsx') #data path
df = pd.DataFrame(data,columns = ['Time','Background','Tcells','Parasite ID','Intensity'])
#df["Intensity_scale"] = np.log10(df.Intensity)
#df["Intensity_scale1"] = df.Intensity_scale.fillna(df.Intensity_scale.mean())
df["Time_1"] = df.Time/60.0
df["Intensity_scale"] = df.Intensity.fillna(df.Intensity.mean())
df["Background_scale"] = df.Background.fillna(df.Background.mean())
df["VI_Index"] = np.log10(df["Intensity_scale"]/df["Background_scale"])
#df.loc[(df.Intensity_scale1>np.mean(df.Intensity_scale1))|((df.Intensity_scale1<=np.mean(df.Intensity_scale1)))]
from sklearn import preprocessing
#df["time_scaled"] = preprocessing.scale(df.Time.values)
#print (df)
#print (df['Time from T transfer (min)'], df['Parasite ID']==1)
#df["Intensity_scale2"]=df.Intensity_scale>np.mean(df.Intensity_scale1)
print(df)
import sys
print(sys.path)
# Out:
#           Time  Background  Tcells  Parasite ID  Intensity     Time_1  \
# 0     240.0000        51.2       5            1      170.8   4.000000
# 1     241.1589        54.0       5            1      198.3   4.019315
# 2     242.3178        53.9       5            1      192.4   4.038630
# 3     243.4767        51.9       5            1      192.5   4.057945
# 4     244.6356        54.3       5            1      193.7   4.077260
# ...        ...         ...     ...          ...        ...        ...
# 2114  639.8325        69.7       0           32      151.3  10.663875
# 2115  645.2825        70.6       0           32      154.9  10.754708
# 2116  650.7325        68.4       0           32      145.0  10.845542
# 2117  656.1825        67.7       0           32      154.7  10.936375
# 2118  661.6325        70.5       0           32      152.3  11.027208
#
#       Intensity_scale  Background_scale  VI_Index
# 0               170.8              51.2  0.523218
# 1               198.3              54.0  0.564929
# 2               192.4              53.9  0.552616
# 3               192.5              51.9  0.569263
# 4               193.7              54.3  0.552330
# ...               ...               ...       ...
# 2114            151.3              69.7  0.336606
# 2115            154.9              70.6  0.341247
# 2116            145.0              68.4  0.326312
# 2117            154.7              67.7  0.358902
# 2118            152.3              70.5  0.334511
#
# [2119 rows x 9 columns]
# ['/Users/soumenbera', '/Users/soumenbera/opt/anaconda3/lib/python38.zip', '/Users/soumenbera/opt/anaconda3/lib/python3.8', '/Users/soumenbera/opt/anaconda3/lib/python3.8/lib-dynload', '', '/Users/soumenbera/.local/lib/python3.8/site-packages', '/Users/soumenbera/opt/anaconda3/lib/python3.8/site-packages', '/Users/soumenbera/opt/anaconda3/lib/python3.8/site-packages/aeosa', '/Users/soumenbera/opt/anaconda3/lib/python3.8/site-packages/asteval-0.9.19-py3.8.egg', '/Users/soumenbera/opt/anaconda3/lib/python3.8/site-packages/uncertainties-3.1.4-py3.8.egg', '/Users/soumenbera/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/Users/soumenbera/.ipython']

# %%
df.loc[(df.VI_Index> 0.3)|(df.VI_Index <= 0.3)]
df["VI_Index_1"]=df.VI_Index < 0.3
print(df)
# Out:
#           Time  Background  Tcells  Parasite ID  Intensity     Time_1  \
# 0     240.0000        51.2       5            1      170.8   4.000000
# 1     241.1589        54.0       5            1      198.3   4.019315
# 2     242.3178        53.9       5            1      192.4   4.038630
# 3     243.4767        51.9       5            1      192.5   4.057945
# 4     244.6356        54.3       5            1      193.7   4.077260
# ...        ...         ...     ...          ...        ...        ...
# 2114  639.8325        69.7       0           32      151.3  10.663875
# 2115  645.2825        70.6       0           32      154.9  10.754708
# 2116  650.7325        68.4       0           32      145.0  10.845542
# 2117  656.1825        67.7       0           32      154.7  10.936375
# 2118  661.6325        70.5       0           32      152.3  11.027208
#
#       Intensity_scale  Background_scale  VI_Index  VI_Index_1
# 0               170.8              51.2  0.523218       False
# 1               198.3              54.0  0.564929       False
# 2               192.4              53.9  0.552616       False
# 3               192.5              51.9  0.569263       False
# 4               193.7              54.3  0.552330       False
# ...               ...               ...       ...         ...
# 2114            151.3              69.7  0.336606       False
# 2115            154.9              70.6  0.341247       False
# 2116            145.0              68.4  0.326312       False
# 2117            154.7              67.7  0.358902       False
# 2118            152.3              70.5  0.334511       False
#
# [2119 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
j = 1
df2=[]
for i in range(32):
    df1=(df[df['Parasite ID']==j]) # separate the data according to parasite id 
    df2.append(df1)
    j=j+1
#for i in range(len(df['Parasite ID'])):
 #   if df['Parasite ID'][i]==j:
        
    #else: 
      #  j=j+1
        
#import matplotlib.pyplot as plt
#for i in range(len(df['Tcells']))    
#plt.plot(df['Time from T transfer (min)'],df['Tcells'])

# %%
print(df2[18])
# Out:
#        Time  Background  Tcells  Parasite ID  Intensity     Time_1  \
# 1463  480.0        57.1       4           19      174.5   8.000000
# 1464  485.0        60.0       4           19      180.7   8.083333
# 1465  490.0        61.0       4           19      204.6   8.166667
# 1466  495.0        59.1       4           19      171.8   8.250000
# 1467  500.0        61.3       4           19      178.4   8.333333
# 1468  505.0        61.2       4           19      191.9   8.416667
# 1469  510.0        62.0       4           19      187.4   8.500000
# 1470  515.0        61.2       4           19      200.5   8.583333
# 1471  520.0        59.6       4           19      177.4   8.666667
# 1472  525.0        61.4       4           19      177.9   8.750000
# 1473  530.0        61.8       3           19      188.8   8.833333
# 1474  535.0        62.4       3           19      219.1   8.916667
# 1475  540.0        63.0       3           19      139.5   9.000000
# 1476  545.0        73.0       3           19      160.4   9.083333
# 1477  550.0        74.9       3           19      177.9   9.166667
# 1478  555.0        74.9       3           19      191.1   9.250000
# 1479  560.0        76.4       3           19      203.0   9.333333
# 1480  565.0        74.4       3           19      165.8   9.416667
# 1481  570.0        74.0       3           19      148.9   9.500000
# 1482  575.0        74.6       3           19      156.3   9.583333
# 1483  580.0        73.6       3           19      142.6   9.666667
# 1484  585.0        75.1       3           19      128.2   9.750000
# 1485  590.0        74.5       4           19      116.3   9.833333
# 1486  595.0        76.8       3           19      125.2   9.916667
# 1487  600.0        76.4       3           19      117.8  10.000000
# 1488  605.0        75.7       3           19      109.9  10.083333
# 1489  610.0        73.9       3           19      174.7  10.166667
# 1490  615.0        77.8       3           19      165.4  10.250000
# 1491  620.0        78.6       3           19      147.0  10.333333
# 1492  625.0        78.6       3           19      147.0  10.416667
# 1493  630.0        80.9       3           19      134.6  10.500000
# 1494  635.0        81.1       3           19      122.9  10.583333
# 1495  640.0        79.5       3           19      107.5  10.666667
# 1496  645.0        81.1       3           19      106.7  10.750000
# 1497  650.0        82.8       3           19      115.6  10.833333
# 1498  655.0        80.8       3           19      106.6  10.916667
# 1499  660.0        81.3       3           19      101.9  11.000000
# 1500  665.0        82.7       3           19      100.1  11.083333
# 1501  670.0        82.7       3           19       90.6  11.166667
# 1502  675.0       139.5       3           19      170.0  11.250000
# 1503  680.0       134.9       3           19      156.5  11.333333
# 1504  685.0       139.8       3           19      168.4  11.416667
# 1505  690.0       141.1       3           19      145.2  11.500000
# 1506  695.0       141.9       3           19      141.8  11.583333
# 1507  700.0       136.4       3           19      137.4  11.666667
# 1508  705.0       138.4       3           19      139.3  11.750000
# 1509  710.0       137.3       4           19      137.0  11.833333
#
#       Intensity_scale  Background_scale  VI_Index  VI_Index_1
# 1463            174.5              57.1  0.485159       False
# 1464            180.7              60.0  0.478807       False
# 1465            204.6              61.0  0.525576       False
# 1466            171.8              59.1  0.463436       False
# 1467            178.4              61.3  0.463934       False
# 1468            191.9              61.2  0.496324       False
# 1469            187.4              62.0  0.480378       False
# 1470            200.5              61.2  0.515363       False
# 1471            177.4              59.6  0.473707       False
# 1472            177.9              61.4  0.462008       False
# 1473            188.8              61.8  0.485014       False
# 1474            219.1              62.4  0.545458       False
# 1475            139.5              63.0  0.345234       False
# 1476            160.4              73.0  0.341882       False
# 1477            177.9              74.9  0.375694       False
# 1478            191.1              74.9  0.406779       False
# 1479            203.0              76.4  0.424403       False
# 1480            165.8              74.4  0.348012       False
# 1481            148.9              74.0  0.303663       False
# 1482            156.3              74.6  0.321220       False
# 1483            142.6              73.6  0.287242        True
# 1484            128.2              75.1  0.232248        True
# 1485            116.3              74.5  0.193423        True
# 1486            125.2              76.8  0.212243        True
# 1487            117.8              76.4  0.188052        True
# 1488            109.9              75.7  0.161902        True
# 1489            174.7              73.9  0.373648       False
# 1490            165.4              77.8  0.327556       False
# 1491            147.0              78.6  0.271895        True
# 1492            147.0              78.6  0.271895        True
# 1493            134.6              80.9  0.221097        True
# 1494            122.9              81.1  0.180531        True
# 1495            107.5              79.5  0.131041        True
# 1496            106.7              81.1  0.119144        True
# 1497            115.6              82.8  0.144927        True
# 1498            106.6              80.8  0.120346        True
# 1499            101.9              81.3  0.098084        True
# 1500            100.1              82.7  0.082929        True
# 1501             90.6              82.7  0.039623        True
# 1502            170.0             139.5  0.085875        True
# 1503            156.5             134.9  0.064502        True
# 1504            168.4             139.8  0.080835        True
# 1505            145.2             141.1  0.012440        True
# 1506            141.8             141.9 -0.000306        True
# 1507            137.4             136.4  0.003172        True
# 1508            139.3             138.4  0.002815        True
# 1509            137.0             137.3 -0.000950        True

# %%
import numpy as np
import matplotlib
import math
fig,axes = plt.subplots(figsize=(30, 26),nrows=4, ncols=2, sharex=True)
for ax,i in zip(axes.flat,[,6,7,8,11,16,17,18,19,21,22,23,26,27]):
#for ax,i in zip(axes.flat,range(32)):
    p=0
    q=0
    #lt.plot(df2[i]['Time from T transfer (min)'], df2[i]['Original Parasite Intensity'])
    #plt.plot(df2[i]['Time'],np.log10(df2[i]['Intensity']))
    from sklearn import linear_model
    regr = linear_model.LinearRegression()
    #X = df2[i].time_scaled.values.reshape(-1,1)
    #y = df2[i].Intensity_scale1.values.reshape(-1,1)
    X = df2[i].VI_Index.values.reshape(-1,1)
    y = df2[i].Tcells.values.reshape(-1,1)
    model=regr.fit(X, y)
    # fit our model to the data
#model.fit(x[:, np.newaxis], y)

# and let's plot what this relationship looks like 
    xfit = X
    yfit = regr.predict(X)
    ax.scatter(X, y,color='grey',marker = 'o', s =24)
    ax.plot(xfit, yfit, color = 'blue', linewidth = 4)
    ax.set_ylim([-0.0,10])
    p = regr.coef_[0]
    q = regr.intercept_
    t=i+1
    ax.text(0.42,9, 'Parasite Id:%i'%t, fontsize=24)
    ax.text(0.42,8, 'coefficient:%0.2f'%p, fontsize=24)
    ax.text(0.42,7,'Intercept:%0.2f'%q, fontsize=24)
    ax.tick_params(labelsize=24)
    ax.tick_params(labelsize=24)
    ax.axhline(y=0.2, color='k', linestyle='--', alpha=1, linewidth=0.5)
    if i==7:
        ax.set_ylabel('Tcells', fontsize=28)
    if i==26:
        ax.set_xlabel('VI', fontsize=28)
    #plt.show()
    #print(i)
    #print(regr.coef_[0])
    #print(regr.intercept_)
    t=0
    r_sq = model.score(X,y)
    print(r_sq)
fig.tight_layout()
#fig.savefig('/home/soumen/Documents/regression-VI-Tcells.png', format='png', dpi=300)
# Out:
#   File "<ipython-input-5-13520fcf9aa0>", line 5
#     for ax,i in zip(axes.flat,[,6,7,8,11,16,17,18,19,21,22,23,26,27]):
#                                ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib
import statsmodels.api as sm
from scipy import stats
import scipy.stats
import math
fig,axes = plt.subplots(figsize=(8, 18),nrows=8, ncols=1, sharex=True)
for ax,i in zip(axes.flat,[6,7,8,17,19,22,23,27]):
#for ax,i in zip(axes.flat,range(32)):
    p=0
    q=0
    #lt.plot(df2[i]['Time from T transfer (min)'], df2[i]['Original Parasite Intensity'])
    #plt.plot(df2[i]['Time'],np.log10(df2[i]['Intensity']))
    from sklearn import linear_model
    regr = linear_model.LinearRegression()
    #X = df2[i].time_scaled.values.reshape(-1,1)
    #y = df2[i].Intensity_scale1.values.reshape(-1,1)
    y = df2[i].VI_Index.values.reshape(-1,1)
    X = df2[i].Tcells.values.reshape(-1,1)
    model=regr.fit(X, y)
    X2 = sm.add_constant(X)
    est = sm.OLS(y, X2)
    est2 = est.fit()
    print(est2.summary())
    # fit our model to the data
#model.fit(x[:, np.newaxis], y)

# and let's plot what this relationship looks like 
    xfit = X
    yfit = regr.predict(X)
    t=i+1
    P = df2[i].VI_Index.values
    n=len(P)
    Q = df2[i].Tcells.values
    r1, p1 = scipy.stats.spearmanr(P, Q)
    r = regr.coef_[0]
    ro = regr.intercept_
    if i == 6 or i == 7 or i== 8:
        ax.scatter(X, y,color='red',marker = 'o', s =24,label = 'Parasite ID: %i'%(t))
        ax.plot(xfit, yfit, color = 'blue', linewidth = 4,label='fit(n=%i,\u03C1=%0.2f,p<0.01)'%(n,r))
    elif i == 17:
        ax.scatter(X, y,color='red',marker = '^', s =24,label = 'Parasite ID: %i'%t)
        ax.plot(xfit, yfit, color = 'blue', linewidth = 4,label='fit(n=%i,\u03C1=%0.2f,p<0.01)'%(n,r))
    elif i == 19:
        ax.scatter(X, y,color='grey',marker = 's', s =24,label = 'Parasite ID: %i'%t)
        ax.plot(xfit, yfit, color = 'blue', linewidth = 4,label='fit(n=%i,\u03C1=%0.2f,p<0.01)'%(n,r))
    elif i== 23:
        ax.scatter(X, y,color='red',marker = '>', s =24,label = 'Parasite ID: %i'%t)
        ax.plot(xfit, yfit, color = 'blue', linewidth = 4,label='fit(n=%i,\u03C1=%0.2f,p~%0.2f)'%(n,r,p1))    
    elif i== 22:
        ax.scatter(X, y,color='red',marker = '>', s =24,label = 'Parasite ID: %i'%t)
        ax.plot(xfit, yfit, color = 'blue', linewidth = 4,label='fit(n=%i,\u03C1=%0.2f,p<0.01)'%(n,r))
    else:
        ax.scatter(X, y,color='red',marker = 'D', s =24,label = 'Parasite ID: %i'%t)
        ax.plot(xfit, yfit, color = 'blue', linewidth = 4,label='fit(n=%i,\u03C1=%0.2f,p~%0.2f)'%(n,r,p1))
    ax.legend(loc='upper right', prop={'size': 16})
    ax.set_yticks([0,0.25,0.5,0.75,1])
    ax.set_xlim([-0.1,10])
    #ax.set_ylim([0.05,0.9])
    p = regr.coef_[0]
    q = regr.intercept_
    t=i+1
    #ax.text(1,0.75, 'Parasite Id:%i'%t, fontsize=20)
    #ax.text(0.42,8, 'coefficient:%0.2f'%p, fontsize=24)
    #ax.text(0.42,7,'Intercept:%0.2f'%q, fontsize=24)
    ax.tick_params(labelsize=24)
    ax.tick_params(labelsize=24)
    ax.axhline(y=0.2, color='k', linestyle='--', alpha=1, linewidth=0.5)
    if i==19:
        ax.set_ylabel('VI', fontsize=22)
    if i==27:
        ax.set_xlabel('# T cell/Cluster', fontsize=22)
    #plt.show()
    #print(i)
    print(regr.coef_[0])
    print(regr.intercept_)
    t=0
    r_sq = model.score(X,y)
    print(r_sq)
fig.tight_layout()
fig.savefig('/Users/soumenbera/Documents/regression-VI-mouse-wise-id.png', format='png', dpi=300)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     44.50
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):           9.84e-10
# Time:                        11:11:17   Log-Likelihood:                 199.31
# No. Observations:                 115   AIC:                            -394.6
# Df Residuals:                     113   BIC:                            -389.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6913      0.071      9.671      0.000       0.550       0.833
# x1            -0.0660      0.010     -6.671      0.000      -0.086      -0.046
# ==============================================================================
# Omnibus:                        8.768   Durbin-Watson:                   0.591
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):               15.689
# Skew:                          -0.241   Prob(JB):                     0.000392
# Kurtosis:                       4.744   Cond. No.                         131.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.06603375]
# [0.69125523]
# 0.28251995384811623
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     42.58
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):           1.99e-09
# Time:                        11:11:17   Log-Likelihood:                 248.76
# No. Observations:                 115   AIC:                            -493.5
# Df Residuals:                     113   BIC:                            -488.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2768      0.031      8.962      0.000       0.216       0.338
# x1            -0.0225      0.003     -6.525      0.000      -0.029      -0.016
# ==============================================================================
# Omnibus:                      101.887   Durbin-Watson:                   0.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1027.481
# Skew:                           3.010   Prob(JB):                    7.68e-224
# Kurtosis:                      16.349   Cond. No.                         107.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.02254902]
# [0.27675588]
# 0.2736884444675175
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     9.500
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):            0.00258
# Time:                        11:11:17   Log-Likelihood:                 305.54
# No. Observations:                 115   AIC:                            -607.1
# Df Residuals:                     113   BIC:                            -601.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1957      0.008     23.693      0.000       0.179       0.212
# x1            -0.0085      0.003     -3.082      0.003      -0.014      -0.003
# ==============================================================================
# Omnibus:                       13.934   Durbin-Watson:                   0.512
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.244
# Skew:                           0.870   Prob(JB):                     0.000489
# Kurtosis:                       3.394   Cond. No.                         17.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.00849975]
# [0.19573206]
# 0.07754763320504976
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.500
# Method:                 Least Squares   F-statistic:                     46.91
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):           1.71e-08
# Time:                        11:11:17   Log-Likelihood:                 35.181
# No. Observations:                  47   AIC:                            -66.36
# Df Residuals:                      45   BIC:                            -62.66
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8719      0.076     11.495      0.000       0.719       1.025
# x1            -0.1712      0.025     -6.849      0.000      -0.221      -0.121
# ==============================================================================
# Omnibus:                        4.581   Durbin-Watson:                   0.377
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                4.324
# Skew:                           0.688   Prob(JB):                        0.115
# Kurtosis:                       2.437   Cond. No.                         14.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.17115817]
# [0.87187839]
# 0.510399542790682
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.265
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     32.53
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):           1.48e-07
# Time:                        11:11:17   Log-Likelihood:                 185.67
# No. Observations:                  92   AIC:                            -367.3
# Df Residuals:                      90   BIC:                            -362.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4271      0.010     41.707      0.000       0.407       0.447
# x1            -0.0396      0.007     -5.703      0.000      -0.053      -0.026
# ==============================================================================
# Omnibus:                        5.752   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.114
# Skew:                           0.497   Prob(JB):                       0.0776
# Kurtosis:                       2.412   Cond. No.                         6.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.03961231]
# [0.42711641]
# 0.2654606463026563
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.641
# Method:                 Least Squares   F-statistic:                     122.6
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):           8.84e-17
# Time:                        11:11:17   Log-Likelihood:                 130.55
# No. Observations:                  69   AIC:                            -257.1
# Df Residuals:                      67   BIC:                            -252.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5444      0.026     21.179      0.000       0.493       0.596
# x1            -0.0508      0.005    -11.071      0.000      -0.060      -0.042
# ==============================================================================
# Omnibus:                        9.696   Durbin-Watson:                   0.571
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.381
# Skew:                          -0.815   Prob(JB):                      0.00918
# Kurtosis:                       3.780   Cond. No.                         33.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.05075685]
# [0.54438596]
# 0.6465781595745619
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     2.984
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):             0.0875
# Time:                        11:11:17   Log-Likelihood:                 121.86
# No. Observations:                  92   AIC:                            -239.7
# Df Residuals:                      90   BIC:                            -234.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5243      0.027     19.397      0.000       0.471       0.578
# x1            -0.0416      0.024     -1.727      0.088      -0.089       0.006
# ==============================================================================
# Omnibus:                       28.742   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.747
# Skew:                           0.302   Prob(JB):                       0.0343
# Kurtosis:                       1.819   Cond. No.                         7.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.04158266]
# [0.5243127]
# 0.03209147197560902
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.6987
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):              0.411
# Time:                        11:11:17   Log-Likelihood:                 5.2759
# No. Observations:                  28   AIC:                            -6.552
# Df Residuals:                      26   BIC:                            -3.887
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4497      0.069      6.486      0.000       0.307       0.592
# x1            -0.0703      0.084     -0.836      0.411      -0.243       0.103
# ==============================================================================
# Omnibus:                        8.626   Durbin-Watson:                   0.182
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.307
# Skew:                          -1.334   Prob(JB):                       0.0157
# Kurtosis:                       2.963   Cond. No.                         3.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [-0.07034899]
# [0.44968016]
# 0.026170743900924776

# %%
import numpy as np
import matplotlib
import math
import scipy.stats
fig,axes = plt.subplots(figsize=(30, 26),nrows=4, ncols=4, sharex=True)
for ax,i in zip(axes.flat,[0,2,3,6,7,8,11,16,17,18,19,21,22,23,26,27]):
#for ax,i in zip(axes.flat,range(32)):
    p=0
    q=0
    #lt.plot(df2[i]['Time from T transfer (min)'], df2[i]['Original Parasite Intensity'])
    #plt.plot(df2[i]['Time'],np.log10(df2[i]['Intensity']))
    from sklearn import linear_model
    regr = linear_model.LinearRegression()
    #X = df2[i].time_scaled.values.reshape(-1,1)
    #y = df2[i].Intensity_scale1.values.reshape(-1,1)
    X = df2[i].VI_Index.values.reshape(-1,1)
    y = df2[i].Tcells.values.reshape(-1,1)
    model=regr.fit(X, y)
    # fit our model to the data
#model.fit(x[:, np.newaxis], y)

# and let's plot what this relationship looks like 
    xfit = X
    yfit = regr.predict(X)
    ax.scatter(X, y,color='grey',marker = 'o', s =24)
    ax.plot(xfit, yfit, color = 'blue', linewidth = 4)
    ax.set_ylim([0,10.1])
    p = regr.coef_[0]
    q = regr.intercept_
    t=i+1
    P = df2[i].VI_Index.values
    Q = df2[i].Tcells.values
    r1, p1 = scipy.stats.pearsonr(P, Q)
    print(p)
    ax.text(0.42,9, 'Parasite Id:%i'%t, fontsize=24)
    ax.text(0.42,8, 'corrcoef r:%0.2f'%r1, fontsize=24)
    #ax.text(0.42,7,'Intercept:%0.2f'%q, fontsize=24)
    ax.text(0.42,7,'P-value:%f'%p1, fontsize=24)
    ax.tick_params(labelsize=24)
    ax.tick_params(labelsize=24)
    ax.axvline(x=0.2, color='k', linestyle='--', alpha=1, linewidth=0.5)
    if i==7:
        ax.set_ylabel('Tcells', fontsize=28)
    if i==26:
        ax.set_xlabel('VI', fontsize=28)
    #plt.show()
    #print(i)
    #print(regr.coef_[0])
    #print(regr.intercept_)
    t=0
    #r_sq = model.score(X,y)
    print(r1)
fig.tight_layout()
fig.savefig('regression-VI-Tcells.png', format='png',bbox_inches='tight', dpi=300)
# Out:
# [0.98618198]
# 0.44789008602781316
# [11.48806265]
# 0.5873781690347313
# [2.16423541]
# 0.09043742521738438
# [-4.27841758]
# -0.5315260613066078
# [-12.13748967]
# -0.523152410361949
# [-9.12351809]
# -0.2784737567618355
# [7.4199128]
# 0.5083101207953115
# [3.08421821]
# 0.34011459398212185
# [-2.98203434]
# -0.7144225239945071
# [1.31041691]
# 0.5148811306985357
# [-6.70146879]
# -0.5152287320236096
# [1.05245076]
# 0.5129402363949604
# [-12.73873808]
# -0.8041008391828487
# [-0.77175135]
# -0.17914092769551346
# [0.38787816]
# 0.03928943913563473
# [-0.37201307]
# -0.16177374292796917
